# %% [markdown]
# Logistic Optimization Analysis with CRIU-AI (LangGraph Implementation)
#
# ## Important Note on Tooling Choice
#
# This project was originally intended to be implemented using the CrewAI framework.
# However, due to repeated compatibility issues between CrewAI and the Groq LLM
# (including OpenAI API key fallback requirements and model resolution errors),
# the CrewAI-based execution could not be reliably completed using a Groq API key.
#
# To ensure a fully functional, executable, and conceptually correct CRIU-AI system,
# this project is implemented using **LangChain + LangGraph**, which supports Groq
# LLMs natively and allows explicit agent-to-agent workflow orchestration.
#
# This implementation:
# - Preserves the **Crew-AI philosophy**
# - Uses **role-based agents**
# - Executes **sequential reasoning**
# - Requires **only a Groq API key**
# - Avoids OpenAI dependency entirely
#
# The workflow and outputs remain equivalent to a CrewAI-based system and demonstrate
# multi-agent collaboration for logistics optimization.

# %%
# !pip install langchain langgraph langchain-groq pandas
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.2.3)
# Requirement already satisfied: langgraph in /usr/local/lib/python3.12/dist-packages (1.0.5)
# Requirement already satisfied: langchain-groq in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.2.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langgraph) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (3.6.0)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.6.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.13.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph) (1.12.1)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.5.0)

# %%
import pandas as pd
from typing import TypedDict, List
from langchain_groq import ChatGroq
from langgraph.graph import StateGraph

# %%
# Use your Groq API key here
llm = ChatGroq(
    groq_api_key="",  # replace with actual key
    model_name="llama-3.3-70b-versatile",  # current supported Groq model
    temperature=0.2
)

def llm_invoke(prompt: str):
    return llm.invoke(prompt).content

# %%
data = pd.DataFrame({
    "product": ["Laptop", "Mobile", "Headphones"],
    "monthly_demand": [1200, 2500, 1800],
    "current_inventory": [800, 2600, 1000],
    "lead_time_days": [7, 3, 5],
    "transport_cost_per_unit": [12, 8, 5]
})

data
# Out:
#       product  monthly_demand  current_inventory  lead_time_days  \
# 0      Laptop            1200                800               7
# 1      Mobile            2500               2600               3
# 2  Headphones            1800               1000               5
#
#    transport_cost_per_unit
# 0                       12
# 1                        8
# 2                        5

# %%
class LogisticsState(TypedDict):
    products: List[dict]
    data_summary: str
    analysis: str
    strategy: str
    final_decision: str

# %%
def logistics_analyst(state: LogisticsState) -> LogisticsState:
    prompt = f"""
You are a logistics analyst.

Analyze the following products and logistics data:

{state['products']}

Focus on:
- Demand vs Inventory gaps
- Lead time risks
- Cost inefficiencies

Provide a concise analytical summary.
"""
    response = llm_invoke(prompt)
    return {**state, "analysis": response}

# %%
def optimization_strategist(state: LogisticsState) -> LogisticsState:
    prompt = f"""
You are a logistics optimization strategist.

Based on the following analysis:

{state['analysis']}

Create a practical optimization strategy including:
- Inventory replenishment
- Route or cost optimization
- Risk mitigation actions
"""
    response = llm_invoke(prompt)
    return {**state, "strategy": response}

# %%
def decision_integrator(state: LogisticsState) -> LogisticsState:
    prompt = f"""
You are a senior logistics decision integrator.

Inputs:
Analysis: {state['analysis']}
Strategy: {state['strategy']}

Task:
Produce a final executive-level decision report including:
1. Key findings
2. Recommendations
3. Expected impact
4. Assumptions and risks
"""
    response = llm_invoke(prompt)
    return {**state, "final_decision": response}

# %%
graph = StateGraph(LogisticsState)

graph.add_node("logistics_analyst", logistics_analyst)
graph.add_node("optimization_strategist", optimization_strategist)
graph.add_node("decision_integrator", decision_integrator)

graph.set_entry_point("logistics_analyst")

graph.add_edge("logistics_analyst", "optimization_strategist")
graph.add_edge("optimization_strategist", "decision_integrator")

app = graph.compile()

# %%
initial_state = {
    "products": data.to_dict(orient="records"),
    "data_summary": "",
    "analysis": "",
    "strategy": "",
    "final_decision": ""
}

# %%
result = app.invoke(initial_state)

# %%
print("=== LOGISTICS ANALYSIS ===")
print(result["analysis"])

print("\n=== OPTIMIZATION STRATEGY ===")
print(result["strategy"])

print("\n=== FINAL DECISION (INTEGRATED) ===")
print(result["final_decision"])
# Out:
# === LOGISTICS ANALYSIS ===
# **Logistics Analysis Summary**
#
# Based on the provided data, the following key insights are identified:
#
# 1. **Demand vs Inventory gaps**:
# 	* Laptop: 400 units short (1200 monthly demand - 800 current inventory), indicating a potential stockout risk.
# 	* Mobile: 100 units excess (2600 current inventory - 2500 monthly demand), suggesting overstocking.
# 	* Headphones: 800 units short (1800 monthly demand - 1000 current inventory), indicating a potential stockout risk.
# 2. **Lead time risks**:
# 	* Laptop: 7-day lead time may exacerbate stockout risks due to high demand and current inventory shortfall.
# 	* Mobile: 3-day lead time is relatively short, minimizing stockout risks.
# 	* Headphones: 5-day lead time may contribute to stockout risks due to high demand and current inventory shortfall.
# 3. **Cost inefficiencies**:
# 	* Laptop: High transport cost per unit ($12) may be optimized by exploring alternative shipping methods or renegotiating with suppliers.
# 	* Mobile: Relatively low transport cost per unit ($8) is acceptable.
# 	* Headphones: Low transport cost per unit ($5) is efficient.
#
# **Recommendations**:
#
# * Replenish Laptop and Headphones inventory to meet monthly demand and mitigate stockout risks.
# * Consider optimizing transportation costs for Laptop shipments.
# * Review Mobile inventory management to avoid overstocking and potential waste.
#
# === OPTIMIZATION STRATEGY ===
# **Logistics Optimization Strategy**
#
# Based on the analysis, our goal is to mitigate stockout risks, optimize transportation costs, and improve overall inventory management. Here's a practical optimization strategy:
#
# **I. Inventory Replenishment**
#
# 1. **Laptop**: Replenish 400 units to meet the monthly demand of 1200 units. Consider expedited shipping to minimize the 7-day lead time risk.
# 2. **Headphones**: Replenish 800 units to meet the monthly demand of 1800 units. Explore options to reduce the 5-day lead time, such as air freight or partnering with a supplier that offers faster shipping.
# 3. **Mobile**: Reduce inventory by 100 units to avoid overstocking and potential waste. Consider implementing a just-in-time (JIT) inventory system to maintain optimal stock levels.
#
# **II. Route or Cost Optimization**
#
# 1. **Laptop**: Explore alternative shipping methods to reduce the high transport cost per unit ($12). Options may include:
# 	* Renegotiating with suppliers to secure better rates.
# 	* Using consolidated shipping to reduce costs.
# 	* Implementing a zone-based pricing system to optimize transportation costs.
# 2. **Headphones**: Maintain the current transportation arrangement, as the low transport cost per unit ($5) is efficient.
# 3. **Mobile**: Continue with the current transportation arrangement, as the relatively low transport cost per unit ($8) is acceptable.
#
# **III. Risk Mitigation Actions**
#
# 1. **Stockout Risk**: Implement a safety stock policy to maintain a buffer inventory of 10-15% for Laptop and Headphones to mitigate stockout risks.
# 2. **Lead Time Risk**: Develop a contingency plan to address potential lead time delays, such as:
# 	* Identifying alternative suppliers with shorter lead times.
# 	* Implementing a drop-shipping program to reduce lead times.
# 	* Maintaining a backup inventory of critical components.
# 3. **Overstocking Risk**: Implement a regular inventory review process to monitor Mobile inventory levels and adjust as needed to avoid overstocking and potential waste.
#
# **IV. Implementation and Monitoring**
#
# 1. **Inventory Management System**: Implement a robust inventory management system to track inventory levels, monitor demand, and optimize replenishment.
# 2. **Key Performance Indicators (KPIs)**: Establish KPIs to measure the effectiveness of the optimization strategy, such as:
# 	* Inventory turnover rate.
# 	* Stockout rate.
# 	* Transportation cost per unit.
# 	* Lead time performance.
# 3. **Regular Review and Adjustment**: Schedule regular review sessions to assess the optimization strategy's performance and make adjustments as needed to ensure continuous improvement.
#
# By implementing this logistics optimization strategy, we can mitigate stockout risks, reduce transportation costs, and improve overall inventory management, ultimately leading to increased customer satisfaction and reduced costs.
#
# === FINAL DECISION (INTEGRATED) ===
# **Executive-Level Decision Report: Logistics Optimization Strategy**
#
# **Introduction:**
# This report summarizes the key findings, recommendations, and expected impact of the logistics optimization strategy designed to mitigate stockout risks, reduce transportation costs, and improve overall inventory management.
#
# **1. Key Findings:**
#
# * Demand vs. inventory gaps: Laptop (400 units short), Headphones (800 units short), and Mobile (100 units excess)
# * Lead time risks: Laptop (7-day lead time), Headphones (5-day lead time), and Mobile (3-day lead time)
# * Cost inefficiencies: Laptop (high transport cost per unit, $12), Mobile (relatively low transport cost per unit, $8), and Headphones (low transport cost per unit, $5)
#
# **2. Recommendations:**
#
# * Replenish Laptop and Headphones inventory to meet monthly demand and mitigate stockout risks
# * Optimize transportation costs for Laptop shipments
# * Review Mobile inventory management to avoid overstocking and potential waste
# * Implement a safety stock policy, contingency plan, and regular inventory review process to mitigate risks
#
# **3. Expected Impact:**
#
# * Mitigation of stockout risks for Laptop and Headphones, resulting in increased customer satisfaction and reduced lost sales
# * Reduction of transportation costs for Laptop shipments, resulting in cost savings and improved profitability
# * Improved inventory management for Mobile, resulting in reduced waste and improved efficiency
# * Enhanced overall logistics performance, resulting in increased competitiveness and revenue growth
#
# **4. Assumptions and Risks:**
#
# * Assumptions:
# 	+ Demand forecasts are accurate
# 	+ Suppliers can meet replenishment demands
# 	+ Transportation costs can be optimized
# * Risks:
# 	+ Lead time delays or supplier insolvency
# 	+ Changes in demand or market conditions
# 	+ Inability to optimize transportation costs
# 	+ Insufficient resources or budget to implement the optimization strategy
#
# **Implementation Plan:**
#
# * Short-term (0-3 months):
# 	+ Replenish Laptop and Headphones inventory
# 	+ Implement safety stock policy and contingency plan
# 	+ Review Mobile inventory management
# * Medium-term (3-6 months):
# 	+ Optimize transportation costs for Laptop shipments
# 	+ Implement regular inventory review process
# 	+ Monitor and adjust the optimization strategy as needed
# * Long-term (6-12 months):
# 	+ Continuously monitor and evaluate the optimization strategy's performance
# 	+ Identify and address any new risks or challenges
# 	+ Explore opportunities for further improvement and expansion
#
# **Conclusion:**
# The logistics optimization strategy outlined in this report is designed to mitigate stockout risks, reduce transportation costs, and improve overall inventory management. By implementing this strategy, we expect to increase customer satisfaction, reduce costs, and improve overall logistics performance. However, it is essential to continuously monitor and adjust the strategy to address any new risks or challenges that may arise.

# %%
question = "What would happen if the monthly demand for Laptops doubled next month?"

answer = llm_invoke(f"""
You are a logistics expert.

Final report: {result['final_decision']}

Question: {question}

Provide a reasoned response based on the analysis and strategy above.
""")

print("=== AD-HOC QUESTION ANSWER ===")
print(answer)
# Out:
# === AD-HOC QUESTION ANSWER ===
# If the monthly demand for Laptops were to double next month, it would significantly impact our current logistics optimization strategy. Based on the report, we are currently 400 units short of meeting the monthly demand for Laptops. If demand were to double, this shortage would increase to 1,200 units (400 units short of original demand + 800 units of additional demand).
#
# Given this scenario, our replenishment strategy would need to be adjusted to meet the new demand. We would need to expedite replenishment of Laptop inventory to avoid stockout risks and potential lost sales. This could involve:
#
# 1. **Emergency replenishment**: We would need to work with our suppliers to expedite shipments and increase the replenishment quantity to meet the new demand.
# 2. **Air freight**: To mitigate lead time risks, we might consider using air freight instead of the current transportation mode, which would reduce the lead time from 7 days to potentially 1-2 days. However, this would increase transportation costs.
# 3. **Contingency planning**: Our contingency plan would need to be activated to manage the increased demand and potential supply chain disruptions.
# 4. **Review of safety stock policy**: We would need to review our safety stock policy to determine if the current levels are sufficient to meet the new demand. We might need to increase safety stock levels to mitigate stockout risks.
#
# In terms of transportation costs, the increased demand would likely lead to higher costs, at least in the short term. However, we could explore options to optimize transportation costs, such as:
#
# 1. **Consolidating shipments**: We could consolidate multiple shipments into a single, larger shipment to reduce transportation costs per unit.
# 2. **Negotiating with suppliers**: We could renegotiate with our suppliers to secure better transportation rates or terms.
# 3. **Exploring alternative transportation modes**: We could explore alternative transportation modes, such as rail or sea freight, which might be more cost-effective for larger shipments.
#
# To mitigate the risks associated with the increased demand, we would need to:
#
# 1. **Closely monitor inventory levels**: We would need to closely monitor inventory levels to ensure that we are meeting demand and avoiding stockouts.
# 2. **Review demand forecasts**: We would need to review our demand forecasts to ensure that they are accurate and reflect the new demand pattern.
# 3. **Communicate with stakeholders**: We would need to communicate with stakeholders, including suppliers, customers, and internal teams, to ensure that everyone is aware of the changes and can respond accordingly.
#
# In conclusion, a doubling of monthly demand for Laptops would require significant adjustments to our logistics optimization strategy. We would need to expedite replenishment, review our safety stock policy, and explore options to optimize transportation costs. Close monitoring of inventory levels, demand forecasts, and communication with stakeholders would be crucial to mitigating the risks associated with the increased demand.
